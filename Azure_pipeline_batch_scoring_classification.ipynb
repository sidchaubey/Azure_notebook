# %% [markdown]
# <a href="https://colab.research.google.com/github/sidchaubey/Azure_notebook/blob/master/Azure_pipeline_batch_scoring_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/tutorials/machine-learning-pipelines-advanced/tutorial-pipeline-batch-scoring-classification.png)

# %% [markdown]
# # Use Azure Machine Learning Pipelines for batch prediction
#
# ## Note
# This notebook uses public preview functionality (ParallelRunStep). Please install azureml-contrib-pipeline-steps package before running this notebook.
#
#
# In this tutorial, you use Azure Machine Learning service pipelines to run a batch scoring image classification job. The example job uses the pre-trained [Inception-V3](https://arxiv.org/abs/1512.00567) CNN (convolutional neural network) Tensorflow model to classify unlabeled images. Machine learning pipelines optimize your workflow with speed, portability, and reuse so you can focus on your expertise, machine learning, rather than on infrastructure and automation. After building and publishing a pipeline, you can configure a REST endpoint to enable triggering the pipeline from any HTTP library on any platform.
#
#
# In this tutorial, you learn the following tasks:
#
# > * Configure workspace and download sample data
# > * Create data objects to fetch and output data
# > * Download, prepare, and register the model to your workspace
# > * Provision compute targets and create a scoring script
# > * Use ParallelRunStep to do batch scoring
# > * Build, run, and publish a pipeline
# > * Enable a REST endpoint for the pipeline
#
# If you donâ€™t have an Azure subscription, create a free account before you begin. Try the [free or paid version of Azure Machine Learning service](https://aka.ms/AMLFree) today.

# %% [markdown]
# ## Prerequisites
#
# * Complete the [setup tutorial](https://docs.microsoft.com/azure/machine-learning/service/tutorial-1st-experiment-sdk-setup) if you don't already have an Azure Machine Learning service workspace or notebook virtual machine.
# * After you complete the setup tutorial, open the **tutorials/tutorial-pipeline-batch-scoring-classification.ipynb** notebook using the same notebook server.
#
# This tutorial is also available on [GitHub](https://github.com/Azure/MachineLearningNotebooks/tree/master/tutorials) if you wish to run it in your own [local environment](how-to-configure-environment.md#local). Run `pip install azureml-sdk[notebooks] azureml-pipeline-core azureml-pipeline-steps pandas requests` to get the required packages.

# %% [markdown]
# ## Configure workspace and create datastore

# %% [markdown]
# Create a workspace object from the existing workspace. A [Workspace](https://docs.microsoft.com/python/api/azureml-core/azureml.core.workspace.workspace?view=azure-ml-py) is a class that accepts your Azure subscription and resource information. It also creates a cloud resource to monitor and track your model runs. `Workspace.from_config()` reads the file **config.json** and loads the authentication details into an object named `ws`. `ws` is used throughout the rest of the code in this tutorial.

# %%
# !pip install azureml-sdk[notebooks] azureml-pipeline-core azureml-pipeline-steps pandas requests
from azureml.core import Workspace
ws = Workspace.from_config()
# Out:
# Requirement already satisfied: azureml-sdk[notebooks] in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: azureml-pipeline-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: azureml-pipeline-steps in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: pandas in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (0.23.4)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (2.23.0)
# Requirement already satisfied: azureml-pipeline~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-train-automl-client~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-train~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-core~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0.post1)
# Requirement already satisfied: azureml-dataprep[fuse]<1.4.10a,>=1.4.6a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.6)
# Requirement already satisfied: azureml-contrib-notebook~=1.4.0; extra == "notebooks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-widgets~=1.4.0; extra == "notebooks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-train-core~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-pipeline-steps) (1.4.0)
# Requirement already satisfied: pytz>=2011k in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.9.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests) (1.24.2)
# Requirement already satisfied: azureml-automl-core~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.4.0->azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: azureml-telemetry~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-automl-client~=1.4.0->azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: pathspec in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.8.0)
# Requirement already satisfied: ndg-httpsclient in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.5.1)
# Requirement already satisfied: pyopenssl in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (19.0.0)
# Requirement already satisfied: docker in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (4.2.0)
# Requirement already satisfied: SecretStorage in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (3.1.1)
# Requirement already satisfied: PyJWT in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.7.1)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (9.0.0)
# Requirement already satisfied: azure-common>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.1.25)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (2.7)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (2.2.0)
# Requirement already satisfied: ruamel.yaml<=0.15.89,>=0.15.35 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.15.89)
# Requirement already satisfied: msrest>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.6.13)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.61.1)
# Requirement already satisfied: contextlib2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.6.0)
# Requirement already satisfied: jmespath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.9.5)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (2.8.0)
# Requirement already satisfied: msrestazure>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.6.3)
# Requirement already satisfied: adal>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.2.2)
# Requirement already satisfied: jsonpickle in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.4.1)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.60.0)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.4.0->azureml-sdk[notebooks]) (9.0.0)
# Requirement already satisfied: dotnetcore2>=2.1.13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (2.1.13)
# Requirement already satisfied: azure-identity<1.3.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.2.2)
# Requirement already satisfied: azureml-dataprep-native<15.0.0,>=14.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (14.1.0)
# Requirement already satisfied: fusepy>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (3.0.1)
# Requirement already satisfied: ipython in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (7.8.0)
# Requirement already satisfied: ipykernel in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (5.1.4)
# Requirement already satisfied: papermill<2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (1.2.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (7.5.1)
# Requirement already satisfied: flake8<=3.7.9,>=3.1.0; python_version >= "3.6" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-core~=1.4.0->azureml-pipeline-steps) (3.7.9)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-train-core~=1.4.0->azureml-pipeline-steps) (1.4.0)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.4.0->azureml-train-automl-client~=1.4.0->azureml-sdk[notebooks]) (0.11.9)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.4.8)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.57.0)
# Requirement already satisfied: jeepney in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.4.1)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.0.post1)
# Requirement already satisfied: asn1crypto>=0.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.0.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.12.3)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.4.0->azureml-sdk[notebooks]) (1.3.0)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.6.0)
# Requirement already satisfied: importlib-metadata in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.23)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2>=2.1.13->azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.5.0)
# Requirement already satisfied: msal-extensions~=0.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (0.1.3)
# Requirement already satisfied: msal<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.2.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.4.0)
# Requirement already satisfied: pickleshare in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.7.5)
# Requirement already satisfied: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (2.4.2)
# Requirement already satisfied: jedi>=0.10 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.15.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.7.0)
# Requirement already satisfied: setuptools>=18.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (41.4.0)
# Requirement already satisfied: backcall in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.3.3)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.4.0)
# Requirement already satisfied: jupyter-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (5.3.3)
# Requirement already satisfied: tornado>=4.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (6.0.3)
# Requirement already satisfied: ansiwrap in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.8.4)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (5.1.2)
# Requirement already satisfied: tenacity in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (6.1.0)
# Requirement already satisfied: tqdm>=4.32.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.45.0)
# Requirement already satisfied: click in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (7.0)
# Requirement already satisfied: future in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.18.2)
# Requirement already satisfied: nbformat in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.4.0)
# Requirement already satisfied: nbconvert>=5.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (5.6.1)
# Requirement already satisfied: entrypoints in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (3.5.1)
# Requirement already satisfied: pyflakes<2.2.0,>=2.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.4.0->azureml-pipeline-steps) (2.1.1)
# Requirement already satisfied: pycodestyle<2.6.0,>=2.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.4.0->azureml-pipeline-steps) (2.5.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.4.0->azureml-pipeline-steps) (0.6.1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.4.0->azureml-sdk[notebooks]) (2.19)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.4.0->azureml-sdk[notebooks]) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata->jsonpickle->azureml-core~=1.4.0->azureml-sdk[notebooks]) (0.6.0)
# Requirement already satisfied: portalocker~=1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.1.3->azure-identity<1.3.0,>=1.2.0->azureml-dataprep[fuse]<1.4.10a,>=1.4.6a->azureml-sdk[notebooks]) (1.7.0)
# Requirement already satisfied: parso>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jedi>=0.10->ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.6.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.1.7)
# Requirement already satisfied: ipython-genutils in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from traitlets>=4.2->ipython->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.2.0)
# Requirement already satisfied: jupyter-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (4.5.0)
# Requirement already satisfied: pyzmq>=13 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jupyter-client->ipykernel->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (18.1.0)
# Requirement already satisfied: textwrap3>=0.9.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.9.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbformat->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (3.0.2)
# Requirement already satisfied: testpath in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.4.2)
# Requirement already satisfied: bleach in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (1.4.2)
# Requirement already satisfied: jinja2>=2.4 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (2.10.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.8.4)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (6.0.0)
# Requirement already satisfied: more-itertools in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from zipp>=0.5->importlib-metadata->jsonpickle->azureml-core~=1.4.0->azureml-sdk[notebooks]) (7.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (19.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.15.4)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from bleach->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (1.1.1)
# Requirement already satisfied: terminado>=0.8.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.8.2)
# Requirement already satisfied: Send2Trash in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (1.5.0)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.4.0; extra == "notebooks"->azureml-sdk[notebooks]) (0.7.1)

# %% [markdown]
# ### Create a datastore for sample images
#
# Get the ImageNet evaluation public data sample from the public blob container `sampledata` on the account `pipelinedata`. Calling `register_azure_blob_container()` makes the data available to the workspace under the name `images_datastore`. Then specify the workspace default datastore as the output datastore, which you use for scoring output in the pipeline.

# %%
from azureml.core.datastore import Datastore

batchscore_blob = Datastore.register_azure_blob_container(ws, 
                      datastore_name="images_datastore", 
                      container_name="sampledata", 
                      account_name="pipelinedata", 
                      overwrite=True)

def_data_store = ws.get_default_datastore()

# %% [markdown]
# ## Create data objects
#
# When building pipelines, `Dataset` objects are used for reading data from workspace datastores, and `PipelineData` objects are used for transferring intermediate data between pipeline steps.
#
# This batch scoring example only uses one pipeline step, but in use-cases with multiple steps, the typical flow will include:
#
# 1. Using `Dataset` objects as **inputs** to fetch raw data, performing some transformations, then **outputting** a `PipelineData` object.
# 1. Use the previous step's `PipelineData` **output object** as an *input object*, repeated for subsequent steps.
#
# For this scenario you create `Dataset` objects corresponding to the datastore directories for both the input images and the classification labels (y-test values). You also create a `PipelineData` object for the batch scoring output data.

# %%
from azureml.core.dataset import Dataset
from azureml.pipeline.core import PipelineData

input_images = Dataset.File.from_files((batchscore_blob, "batchscoring/images/"))
label_ds = Dataset.File.from_files((batchscore_blob, "batchscoring/labels/*.txt"))
output_dir = PipelineData(name="scores", 
                          datastore=def_data_store, 
                          output_path_on_compute="batchscoring/results")

# %% [markdown]
# Next, we need to register the datasets with the workspace.

# %%
input_images = input_images.register(workspace = ws, name = "input_images")
label_ds = label_ds.register(workspace = ws, name = "label_ds")

# %%
## Download and register the model

# %% [markdown]
# Download the pre-trained Tensorflow model to use it for batch scoring in the pipeline. First create a local directory where you store the model, then download and extract it.

# %%
import os
import tarfile
import urllib.request

if not os.path.isdir("models"):
    os.mkdir("models")
    
response = urllib.request.urlretrieve("http://download.tensorflow.org/models/inception_v3_2016_08_28.tar.gz", "model.tar.gz")
tar = tarfile.open("model.tar.gz", "r:gz")
tar.extractall("models")

# %% [markdown]
# Now you register the model to your workspace, which allows you to easily retrieve it in the pipeline process. In the `register()` static function, the `model_name` parameter is the key you use to locate your model throughout the SDK.

# %%
import shutil
from azureml.core.model import Model

# register downloaded model 
model = Model.register(model_path="models/inception_v3.ckpt",
                       model_name="inception",
                       tags={"pretrained": "inception"},
                       description="Imagenet trained tensorflow inception",
                       workspace=ws)
# remove the downloaded dir after registration if you wish
shutil.rmtree("models")
# Out:
# Registering model inception

# %% [markdown]
# ## Create and attach remote compute target
#
# Azure Machine Learning service pipelines cannot be run locally, and only run on cloud resources. Remote compute targets are reusable virtual compute environments where you run experiments and work-flows. Run the following code to create a GPU-enabled [`AmlCompute`](https://docs.microsoft.com/python/api/azureml-core/azureml.core.compute.amlcompute.amlcompute?view=azure-ml-py) target, and attach it to your workspace. See the [conceptual article](https://docs.microsoft.com/azure/machine-learning/service/concept-compute-target) for more information on compute targets.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget
from azureml.exceptions import ComputeTargetException
compute_name = "gpu-cluster"

# checks to see if compute target already exists in workspace, else create it
try:
    compute_target = ComputeTarget(workspace=ws, name=compute_name)
except ComputeTargetException:
    config = AmlCompute.provisioning_configuration(vm_size="STANDARD_NC6",
                                                   vm_priority="lowpriority", 
                                                   min_nodes=0, 
                                                   max_nodes=1)

    compute_target = ComputeTarget.create(workspace=ws, name=compute_name, provisioning_configuration=config)
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Write a scoring script

# %% [markdown]
# To do the scoring, you create a batch scoring script `batch_scoring.py`, and write it to the current directory. The script takes a minibatch of input images, applies the classification model, and outputs the predictions to a results file.
#
# The script `batch_scoring.py` takes the following parameters, which get passed from the `ParallelRunStep` that you create later:
#
# - `--model_name`: the name of the model being used
# - `--labels_name` : the name of the `Dataset` holding the `labels.txt` file
#
# The pipelines infrastructure uses the `ArgumentParser` class to pass parameters into pipeline steps. For example, in the code below the first argument `--model_name` is given the property identifier `model_name`. In the `main()` function, this property is accessed using `Model.get_model_path(args.model_name)`.

# %% [markdown]
# The pipeline in this tutorial only has one step and writes the output to a file, but for multi-step pipelines, you also use `ArgumentParser` to define a directory to write output data for input to subsequent steps. See the [notebook](https://github.com/Azure/MachineLearningNotebooks/blob/master/how-to-use-azureml/machine-learning-pipelines/nyc-taxi-data-regression-model-building/nyc-taxi-data-regression-model-building.ipynb) for an example of passing data between multiple pipeline steps using the `ArgumentParser` design pattern.

# %% [markdown]
# ## Build and run the pipeline

# %% [markdown]
# Before running the pipeline, you create an object that defines the python environment and dependencies needed by your script `batch_scoring.py`. The main dependency required is Tensorflow, but you also install `azureml-defaults` for background processes from the SDK. Create a `RunConfiguration` object using the dependencies, and also specify Docker and Docker-GPU support.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import DEFAULT_GPU_IMAGE

cd = CondaDependencies.create(pip_packages=["tensorflow-gpu==1.13.1", "azureml-defaults"])

env = Environment(name="parallelenv")
env.python.conda_dependencies=cd
env.docker.base_image = DEFAULT_GPU_IMAGE

# %% [markdown]
# ### Create the configuration to wrap the inference script
# Create the pipeline step using the script, environment configuration, and parameters. Specify the compute target you already attached to your workspace as the target of execution of the script. We will use PythonScriptStep to create the pipeline step.

# %%
from azureml.contrib.pipeline.steps import ParallelRunConfig

parallel_run_config = ParallelRunConfig(
    environment=env,
    entry_script="batch_scoring.py",
    source_directory="scripts",
    output_action="append_row",
    mini_batch_size="20",
    error_threshold=1,
    compute_target=compute_target,
    process_count_per_node=2,
    node_count=1
)

# %% [markdown]
# ### Create the pipeline step
#
# A pipeline step is an object that encapsulates everything you need for running a pipeline including:
#
# * environment and dependency settings
# * the compute resource to run the pipeline on
# * input and output data, and any custom parameters
# * reference to a script or SDK-logic to run during the step
#
# There are multiple classes that inherit from the parent class [`PipelineStep`](https://docs.microsoft.com/python/api/azureml-pipeline-core/azureml.pipeline.core.builder.pipelinestep?view=azure-ml-py) to assist with building a step using certain frameworks and stacks. In this example, you use the [`ParallelRunStep`](https://docs.microsoft.com/en-us/python/api/azureml-contrib-pipeline-steps/azureml.contrib.pipeline.steps.parallelrunstep?view=azure-ml-py) class to define your step logic using a scoring script.
#
# An object reference in the `outputs` array becomes available as an **input** for a subsequent pipeline step, for scenarios where there is more than one step.

# %%
from azureml.contrib.pipeline.steps import ParallelRunStep
from datetime import datetime

parallel_step_name = "batchscoring-" + datetime.now().strftime("%Y%m%d%H%M")

batch_score_step = ParallelRunStep(
    name=parallel_step_name,
    inputs=[input_images.as_named_input("input_images")],
    output=output_dir,
    models=[model],
    arguments=["--model_name", "inception",
               "--labels_name", "label_ds"],
    parallel_run_config=parallel_run_config,
    allow_reuse=False
)

# %% [markdown]
# For a list of all classes for different step types, see the [steps package](https://docs.microsoft.com/python/api/azureml-pipeline-steps/azureml.pipeline.steps?view=azure-ml-py).

# %% [markdown]
# ### Run the pipeline
#
# Now you run the pipeline. First create a `Pipeline` object with your workspace reference and the pipeline step you created. The `steps` parameter is an array of steps, and in this case there is only one step for batch scoring. To build pipelines with multiple steps, you place the steps in order in this array.
#
# Next use the `Experiment.submit()` function to submit the pipeline for execution. You also specify the custom parameter `param_batch_size`. The `wait_for_completion` function will output logs during the pipeline build process, which allows you to see current progress.
#
# Note: The first pipeline run takes roughly **15 minutes**, as all dependencies must be downloaded, a Docker image is created, and the Python environment is provisioned/created. Running it again takes significantly less time as those resources are reused. However, total run time depends on the workload of your scripts and processes running in each pipeline step.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[batch_score_step])
pipeline_run = Experiment(ws, "batch_scoring").submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batchscoring-202005050840 [970db974][90a158f1-4c6b-4c68-978f-73f6275c3a18], (This step will run and generate new outputs)
# Created data reference input_images_0 for StepId [3e8fc72a][acf83cec-af6a-4f83-a85d-a603ea390cae], (Consumers of this data will generate new runs.)
# Submitted PipelineRun dc4bebc2-709e-4c4a-8025-bde64ab6e8ad
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_scoring/runs/dc4bebc2-709e-4c4a-8025-bde64ab6e8ad?wsid=/subscriptions/e52443a5-2969-41ea-8e65-0949be111242/resourcegroups/FaceRec/workspaces/MyFirstML
# PipelineRunId: dc4bebc2-709e-4c4a-8025-bde64ab6e8ad
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_scoring/runs/dc4bebc2-709e-4c4a-8025-bde64ab6e8ad?wsid=/subscriptions/e52443a5-2969-41ea-8e65-0949be111242/resourcegroups/FaceRec/workspaces/MyFirstML
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 473e9f50-8536-49ad-b863-e7cad21021b4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_scoring/runs/473e9f50-8536-49ad-b863-e7cad21021b4?wsid=/subscriptions/e52443a5-2969-41ea-8e65-0949be111242/resourcegroups/FaceRec/workspaces/MyFirstML
# StepRun( batchscoring-202005050840 ) Status: NotStarted
# StepRun( batchscoring-202005050840 ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# StepRun( batchscoring-202005050840 ) Status: Running
# 2020/05/05 08:41:23 Downloading source code...
# 2020/05/05 08:41:27 Finished downloading source code
# 2020/05/05 08:41:27 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/05/05 08:41:28 Successfully set up Docker network: acb_default_network
# 2020/05/05 08:41:28 Setting up Docker configuration...
# 2020/05/05 08:41:28 Successfully set up Docker configuration
# 2020/05/05 08:41:28 Logging in to registry: myfirstmlc2d8e3fd.azurecr.io
# 2020/05/05 08:41:30 Successfully logged into myfirstmlc2d8e3fd.azurecr.io
# 2020/05/05 08:41:30 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/05 08:41:30 Scanning for dependencies...
# 2020/05/05 08:41:30 Successfully scanned dependencies
# 2020/05/05 08:41:30 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base-gpu:intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04@sha256:85cbe68aa7d55ec4f3739fcc3fe04d9c49641700b4ce31d04e1a8bf7bc66acf1
# sha256:85cbe68aa7d55ec4f3739fcc3fe04d9c49641700b4ce31d04e1a8bf7bc66acf1: Pulling from azureml/base-gpu
# f7277927d38a: Pulling fs layer
# 8d3eac894db4: Pulling fs layer
# edf72af6d627: Pulling fs layer
# 3e4f86211d23: Pulling fs layer
# d6e9603ff777: Pulling fs layer
# 5cad422780e2: Pulling fs layer
# 8130687c8acb: Pulling fs layer
# c11e9246d621: Pulling fs layer
# 0dfae24cbbd9: Pulling fs layer
# 0bb049a6d391: Pulling fs layer
# 22a53069998a: Pulling fs layer
# db550b9db251: Pulling fs layer
# 10a826755d7e: Pulling fs layer
# 457c96476eac: Pulling fs layer
# e2d7418d62ad: Pulling fs layer
# a0d6fa61e0b7: Pulling fs layer
# 93f75153ba2d: Pulling fs layer
# 3e4f86211d23: Waiting
# d6e9603ff777: Waiting
# 5cad422780e2: Waiting
# 8130687c8acb: Waiting
# c11e9246d621: Waiting
# 0dfae24cbbd9: Waiting
# 0bb049a6d391: Waiting
# 22a53069998a: Waiting
# db550b9db251: Waiting
# 10a826755d7e: Waiting
# 457c96476eac: Waiting
# e2d7418d62ad: Waiting
# a0d6fa61e0b7: Waiting
# 93f75153ba2d: Waiting
# edf72af6d627: Verifying Checksum
# edf72af6d627: Download complete
# 8d3eac894db4: Verifying Checksum
# 8d3eac894db4: Download complete
# 3e4f86211d23: Verifying Checksum
# 3e4f86211d23: Download complete
# f7277927d38a: Verifying Checksum
# f7277927d38a: Download complete
# f7277927d38a: Pull complete
# 8d3eac894db4: Pull complete
# edf72af6d627: Pull complete
# 3e4f86211d23: Pull complete
# 8130687c8acb: Verifying Checksum
# 8130687c8acb: Download complete
# d6e9603ff777: Verifying Checksum
# d6e9603ff777: Download complete
# 5cad422780e2: Verifying Checksum
# 5cad422780e2: Download complete
# d6e9603ff777: Pull complete
# 5cad422780e2: Pull complete
# 8130687c8acb: Pull complete
# c11e9246d621: Verifying Checksum
# c11e9246d621: Download complete
# 0dfae24cbbd9: Verifying Checksum
# 0dfae24cbbd9: Download complete
# 22a53069998a: Verifying Checksum
# 22a53069998a: Download complete
# db550b9db251: Verifying Checksum
# db550b9db251: Download complete
# 0bb049a6d391: Verifying Checksum
# 0bb049a6d391: Download complete
# 10a826755d7e: Verifying Checksum
# 10a826755d7e: Download complete
# a0d6fa61e0b7: Download complete
# 93f75153ba2d: Verifying Checksum
# 93f75153ba2d: Download complete
# 457c96476eac: Verifying Checksum
# 457c96476eac: Download complete
# e2d7418d62ad: Verifying Checksum
# e2d7418d62ad: Download complete
# c11e9246d621: Pull complete
# 0dfae24cbbd9: Pull complete
# 0bb049a6d391: Pull complete
# 22a53069998a: Pull complete
# db550b9db251: Pull complete
# 10a826755d7e: Pull complete
# 457c96476eac: Pull complete
# e2d7418d62ad: Pull complete
# a0d6fa61e0b7: Pull complete
# 93f75153ba2d: Pull complete
# Digest: sha256:85cbe68aa7d55ec4f3739fcc3fe04d9c49641700b4ce31d04e1a8bf7bc66acf1
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base-gpu:intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04@sha256:85cbe68aa7d55ec4f3739fcc3fe04d9c49641700b4ce31d04e1a8bf7bc66acf1
#  ---> 6fb8d9173f11
# Step 2/15 : USER root
#  ---> Running in 24582003a6d5
# Removing intermediate container 24582003a6d5
#  ---> dd9d7c70c40f
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 8264cc2360f2
# Removing intermediate container 8264cc2360f2
#  ---> 8a252001e9c4
# Step 4/15 : WORKDIR /
#  ---> Running in 32d0d317aefa
# Removing intermediate container 32d0d317aefa
#  ---> fddc98705558
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 3b2246a1aad7
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in fc61e86a5aae
# Removing intermediate container fc61e86a5aae
#  ---> b6b4cc8a2576
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 828764d01eef
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 5d1a5088d86d
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# setuptools-46.1.3    | 663 KB    |            |   0%
# setuptools-46.1.3    | 663 KB    | ########4  |  85%
# setuptools-46.1.3    | 663 KB    | ########## | 100%
#
# psutil-5.7.0         | 332 KB    |            |   0%
# psutil-5.7.0         | 332 KB    | #########8 |  98%
# psutil-5.7.0         | 332 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.1 MB    | #########8 |  98%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########3 |  94%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######5   |  75%
# libgcc-ng-9.1.0      | 8.1 MB    | #########7 |  98%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | #########4 |  95%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | #######8   |  78%
# pip-20.0.2           | 1.9 MB    | #########7 |  98%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########8 |  99%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##5        |  25%
# python-3.6.2         | 27.0 MB   | #####9     |  60%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | ########8  |  89%
# python-3.6.2         | 27.0 MB   | #########8 |  98%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########   |  81%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########  |  90%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | #########  |  91%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting tensorflow-gpu==1.13.1
#   Downloading tensorflow_gpu-1.13.1-cp36-cp36m-manylinux1_x86_64.whl (345.2 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.4.0-py3-none-any.whl (3.0 kB)
# Collecting azure-storage-queue~=2.1
#   Downloading azure_storage_queue-2.1.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-storage-common~=2.1
#   Downloading azure_storage_common-2.1.0-py2.py3-none-any.whl (47 kB)
# Collecting azureml-core~=1.0
#   Downloading azureml_core-1.4.0.post2-py3-none-any.whl (1.3 MB)
# Collecting azureml-telemetry~=1.0
#   Downloading azureml_telemetry-1.4.0-py3-none-any.whl (29 kB)
# Collecting filelock~=3.0
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting azureml-dataprep[fuse,pandas]~=1.1
#   Downloading azureml_dataprep-1.5.0-py3-none-any.whl (26.7 MB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting grpcio>=1.8.6
#   Downloading grpcio-1.28.1-cp36-cp36m-manylinux2010_x86_64.whl (2.8 MB)
# Collecting protobuf>=3.6.1
#   Downloading protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Collecting keras-preprocessing>=1.0.5
#   Downloading Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41 kB)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
# Collecting gast>=0.2.0
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.18.4-cp36-cp36m-manylinux1_x86_64.whl (20.2 MB)
# Collecting six>=1.10.0
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: wheel>=0.26 in /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages (from tensorflow-gpu==1.13.1->-r /azureml-environment-setup/condaenv.61l8l75l.requirements.txt (line 1)) (0.34.2)
# Collecting astor>=0.6.0
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting absl-py>=0.1.6
#   Downloading absl-py-0.9.0.tar.gz (104 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azure-common>=1.1.5
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting cryptography
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting requests
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-9.0.0-py2.py3-none-any.whl (807 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-9.0.0-py2.py3-none-any.whl (525 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.13-py2.py3-none-any.whl (83 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.3-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jmespath
#   Downloading jmespath-0.9.5-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<15.0.0,>=14.1.0
#   Downloading azureml_dataprep_native-14.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting pyarrow>=0.15.*; extra == "pandas"
#   Downloading pyarrow-0.17.0-cp36-cp36m-manylinux2014_x86_64.whl (63.8 MB)
# Collecting pandas>=0.23.4; extra == "pandas"
#   Downloading pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl (10.0 MB)
# Requirement already satisfied: setuptools in /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.1->-r /azureml-environment-setup/condaenv.61l8l75l.requirements.txt (line 1)) (46.1.3.post20200330)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.2-py3-none-any.whl (28 kB)
# Collecting h5py
#   Downloading h5py-2.10.0-cp36-cp36m-manylinux1_x86_64.whl (2.9 MB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.2.1-py2.py3-none-any.whl (88 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages (from requests->azure-storage-common~=2.1->-r /azureml-environment-setup/condaenv.61l8l75l.requirements.txt (line 4)) (2020.4.5.1)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.2.0-py2.py3-none-any.whl (46 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.5.0-py2.py3-none-any.whl (118 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Building wheels for collected packages: termcolor, absl-py, json-logging-py, fusepy, liac-arff, dill
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=ad67dc1fc7b9dfe8e67b9e2450b7a35d8289f1fc42c0c843d04d9d61015dd4a6
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121931 sha256=47685355a7c6d0119e62de5932a93dd94ffa55d613ae1947d6163011a7b80a14
#   Stored in directory: /root/.cache/pip/wheels/c3/af/84/3962a6af7b4ab336e951b7877dcfb758cf94548bb1771e0679
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=8e6674b7b8e340c5e166c1bfdc60ae834f8b2edf926bd5361c9292379fcf77d9
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=8410541b925f243d331cef819b7534fd1ba58ca67231429861899cd7854f635b
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=d289a2bea8874dae7d914eb9161acbaf80530cb0beb7952937bc23f4d01c122d
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=86471cab16780053f60fad6faf07f58c0d43ef31d573d4ddf213593dda058779
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
# Successfully built termcolor absl-py json-logging-py fusepy liac-arff dill
# ERROR: azureml-defaults 1.4.0 has requirement azureml-dataprep[fuse]<1.4.10a,>=1.4.6a, but you'll have azureml-dataprep 1.5.0 which is incompatible.
# Installing collected packages: termcolor, six, grpcio, protobuf, absl-py, mock, numpy, tensorflow-estimator, h5py, keras-applications, keras-preprocessing, werkzeug, markdown, tensorboard, gast, astor, tensorflow-gpu, cloudpickle, distro, dotnetcore2, azureml-dataprep-native, portalocker, urllib3, idna, chardet, requests, PyJWT, msal, msal-extensions, azure-core, pycparser, cffi, cryptography, azure-identity, fusepy, pyarrow, python-dateutil, pytz, pandas, azureml-dataprep, liac-arff, dill, adal, azureml-model-management-sdk, click, itsdangerous, MarkupSafe, Jinja2, flask, gunicorn, isodate, oauthlib, requests-oauthlib, msrest, azure-common, msrestazure, azure-mgmt-resource, websocket-client, docker, azure-mgmt-storage, contextlib2, azure-graphrbac, azure-mgmt-containerregistry, zipp, importlib-metadata, jsonpickle, pyopenssl, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, jmespath, azure-mgmt-authorization, ruamel.yaml, pathspec, jeepney, SecretStorage, backports.weakref, backports.tempfile, azureml-core, json-logging-py, applicationinsights, configparser, azureml-defaults, azure-storage-common, azure-storage-queue, azureml-telemetry, filelock
#
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 absl-py-0.9.0 adal-1.2.3 applicationinsights-0.11.9 astor-0.8.1 azure-common-1.1.25 azure-core-1.5.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-9.0.0 azure-mgmt-storage-9.0.0 azure-storage-common-2.1.0 azure-storage-queue-2.1.0 azureml-core-1.4.0.post2 azureml-dataprep-1.5.0 azureml-dataprep-native-14.1.0 azureml-defaults-1.4.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-telemetry-1.4.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.4.1 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.9.2 dill-0.3.1.1 distro-1.5.0 docker-4.2.0 dotnetcore2-2.1.14 filelock-3.0.12 flask-1.0.3 fusepy-3.0.1 gast-0.3.3 grpcio-1.28.1 gunicorn-19.9.0 h5py-2.10.0 idna-2.9 importlib-metadata-1.6.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.9.5 json-logging-py-0.2 jsonpickle-1.4.1 keras-applications-1.0.8 keras-preprocessing-1.1.0 liac-arff-2.4.0 markdown-3.2.1 mock-4.0.2 msal-1.2.0 msal-extensions-0.1.3 msrest-0.6.13 msrestazure-0.6.3 ndg-httpsclient-0.5.1 numpy-1.18.4 oauthlib-3.1.0 pandas-1.0.3 pathspec-0.8.0 portalocker-1.7.0 protobuf-3.11.3 pyarrow-0.17.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 six-1.14.0 tensorboard-1.13.1 tensorflow-estimator-1.13.0 tensorflow-gpu-1.13.1 termcolor-1.1.0 urllib3-1.25.9 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container 5d1a5088d86d
#  ---> 4df564767823
# Step 9/15 : ENV PATH /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/bin:$PATH
#  ---> Running in 362ebc06d1d3
# Removing intermediate container 362ebc06d1d3
#  ---> ccb95cbf09ea
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14
#  ---> Running in 8c1f9799bb15
# Removing intermediate container 8c1f9799bb15
#  ---> 70e5e9ed65d6
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib:$LD_LIBRARY_PATH
#  ---> Running in 1bcd48100d35
# Removing intermediate container 1bcd48100d35
#  ---> d5738dad4437
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> ed8172a59d0a
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "[]" /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in fc4000a91ff2
# Removing intermediate container fc4000a91ff2
#  ---> 8281b5be1094
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 4d36495f565a
# Removing intermediate container 4d36495f565a
#  ---> ee6e50a3a832
# Step 15/15 : CMD ["bash"]
#  ---> Running in b2fe6331f302
# Removing intermediate container b2fe6331f302
#  ---> 742541f23f3c
# Successfully built 742541f23f3c
# Successfully tagged myfirstmlc2d8e3fd.azurecr.io/azureml/azureml_11354d7ddbde0a198a47ba107c41fe2a:latest
# 2020/05/05 08:47:05 Successfully executed container: acb_step_0
# 2020/05/05 08:47:05 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/05 08:47:05 Pushing image: myfirstmlc2d8e3fd.azurecr.io/azureml/azureml_11354d7ddbde0a198a47ba107c41fe2a:latest, attempt 1
# The push refers to repository [myfirstmlc2d8e3fd.azurecr.io/azureml/azureml_11354d7ddbde0a198a47ba107c41fe2a]
# f7ad7413e4d0: Preparing
# 7b285b1935b6: Preparing
# a89fb88c065f: Preparing
# 849f9525aec7: Preparing
# 1e20dc3e7fb0: Preparing
# 95d717a05201: Preparing
# 978386f03030: Preparing
# 52c46f0dc348: Preparing
# e038214cda9f: Preparing
# 81b82cd24e5d: Preparing
# 59f4f62aa598: Preparing
# 150a69839c4c: Preparing
# 49a8cc5f9aaf: Preparing
# c36fc92de581: Preparing
# 524881d0563d: Preparing
# d05c249e6b9f: Preparing
# fc8a172f94e8: Preparing
# 48001c8a7ddb: Preparing
# 6dce9683cb41: Preparing
# e79142719515: Preparing
# aeda103e78c9: Preparing
# 2558e637fbff: Preparing
# f749b9b0fb21: Preparing
# 95d717a05201: Waiting
# 978386f03030: Waiting
# 52c46f0dc348: Waiting
# e038214cda9f: Waiting
# 81b82cd24e5d: Waiting
# 59f4f62aa598: Waiting
# 150a69839c4c: Waiting
# 49a8cc5f9aaf: Waiting
# c36fc92de581: Waiting
# aeda103e78c9: Waiting
# 524881d0563d: Waiting
# d05c249e6b9f: Waiting
# fc8a172f94e8: Waiting
# 48001c8a7ddb: Waiting
# 6dce9683cb41: Waiting
# 2558e637fbff: Waiting
# e79142719515: Waiting
# f749b9b0fb21: Waiting
# 849f9525aec7: Pushed
# f7ad7413e4d0: Pushed
# a89fb88c065f: Pushed
# 1e20dc3e7fb0: Pushed
# 95d717a05201: Pushed
# 978386f03030: Pushed
# 52c46f0dc348: Pushed
#
# 150a69839c4c: Pushed
# 59f4f62aa598: Pushed
# 81b82cd24e5d: Pushed
# e038214cda9f: Pushed
# 49a8cc5f9aaf: Pushed
# fc8a172f94e8: Pushed
# 48001c8a7ddb: Pushed
# 6dce9683cb41: Pushed
# e79142719515: Pushed
# aeda103e78c9: Pushed
# 2558e637fbff: Pushed
# c36fc92de581: Pushed
# d05c249e6b9f: Pushed
# f749b9b0fb21: Pushed
#
# 7b285b1935b6: Pushed
# 524881d0563d: Pushed
# latest: digest: sha256:e1309f35f4233ce07526425bda9f783334567c4215bdb83cc77e241ab341dbbf size: 5151
# 2020/05/05 08:51:31 Successfully pushed image: myfirstmlc2d8e3fd.azurecr.io/azureml/azureml_11354d7ddbde0a198a47ba107c41fe2a:latest
# 2020/05/05 08:51:31 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 335.372716)
# 2020/05/05 08:51:31 Populating digests for step ID: acb_step_0...
# 2020/05/05 08:51:33 Successfully populated digests for step ID: acb_step_0
# 2020/05/05 08:51:33 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 266.344497)
# 2020/05/05 08:51:33 The following dependencies were found:
# 2020/05/05 08:51:33
# - image:
#     registry: myfirstmlc2d8e3fd.azurecr.io
#     repository: azureml/azureml_11354d7ddbde0a198a47ba107c41fe2a
#     tag: latest
#     digest: sha256:e1309f35f4233ce07526425bda9f783334567c4215bdb83cc77e241ab341dbbf
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base-gpu
#     tag: intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04
#     digest: sha256:85cbe68aa7d55ec4f3739fcc3fe04d9c49641700b4ce31d04e1a8bf7bc66acf1
#   git: {}
#
#
# Run ID: ca1 was successful after 10m11s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e69847f382fde179d7e8996f567b0b8211721240d7a074ff447edc7ed5f1d273_p.txt
# ========================================================================================================================
# 2020-05-05T08:56:22Z Starting output-watcher...
# 2020-05-05T08:56:22Z IsDedicatedCompute == False, starting polling for Low-Pri Preemption
# 5747857791fbe82c25361203f35ef92f2a6244cfbff13493a82c7e3118f313f3
#
# Streaming azureml-logs/65_job_prep-tvmps_e69847f382fde179d7e8996f567b0b8211721240d7a074ff447edc7ed5f1d273_p.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-05-05T08:58:12.807999
# Starting job preparation. Current time:2020-05-05T08:58:13.374757
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 84f3e45c-929a-4576-a0b9-f803c2888a63
# Starting the daemon thread to refresh tokens in background for process with pid = 56
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-05-05T08:58:18.011239
# Acquired lockfile /tmp/473e9f50-8536-49ad-b863-e7cad21021b4-datastore.lock to downloading input data references
# Downloading batchscoring/images/ILSVRC2012_val_00000102.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000103.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000104.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000105.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000106.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000107.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000108.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000109.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000110.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000111.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000112.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000113.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000114.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000115.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000116.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000117.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000118.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000119.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000120.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000121.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000122.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000123.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000124.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000125.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000126.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000127.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000128.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000129.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000130.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000131.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000132.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000133.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000104.JPEG, 1 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000134.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000133.JPEG, 2 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000135.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000135.JPEG, 3 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000136.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000136.JPEG, 4 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000137.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000103.JPEG, 5 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000138.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000102.JPEG, 6 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000139.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000137.JPEG, 7 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000140.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000112.JPEG, 8 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000141.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000117.JPEG, 9 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000142.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000106.JPEG, 10 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000143.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000105.JPEG, 11 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000144.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000116.JPEG, 12 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000145.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000126.JPEG, 13 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000146.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000138.JPEG, 14 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000147.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000118.JPEG, 15 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000148.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000130.JPEG, 16 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000113.JPEG, 17 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000123.JPEG, 18 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000149.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000150.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000151.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000141.JPEG, 19 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000111.JPEG, 20 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000152.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000153.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000109.JPEG, 21 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000154.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000107.JPEG, 22 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000155.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000143.JPEG, 23 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000156.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000108.JPEG, 24 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000157.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000144.JPEG, 25 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000158.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000139.JPEG, 26 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000159.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000128.JPEG, 27 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000160.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000148.JPEG, 28 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000161.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000110.JPEG, 29 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000162.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000124.JPEG, 30 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000163.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000142.JPEG, 31 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000164.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000150.JPEG, 32 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000165.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000151.JPEG, 33 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000166.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000156.JPEG, 34 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000167.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000157.JPEG, 35 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000168.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000125.JPEG, 36 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000169.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000146.JPEG, 37 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000170.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000140.JPEG, 38 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000119.JPEG, 39 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000122.JPEG, 40 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000171.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000172.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000173.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000121.JPEG, 41 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000174.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000115.JPEG, 42 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000175.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000161.JPEG, 43 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000176.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000132.JPEG, 44 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000177.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000114.JPEG, 45 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000162.JPEG, 46 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000178.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000179.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000153.JPEG, 47 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000180.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000149.JPEG, 48 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000181.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000152.JPEG, 49 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000163.JPEG, 50 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000131.JPEG, 51 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000182.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000183.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000184.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000164.JPEG, 52 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000185.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000154.JPEG, 53 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000186.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000155.JPEG, 54 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000187.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000127.JPEG, 55 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000188.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000145.JPEG, 56 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000189.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000168.JPEG, 57 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000190.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000147.JPEG, 58 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000191.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000159.JPEG, 59 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000192.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000173.JPEG, 60 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000193.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000129.JPEG, 61 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000194.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000176.JPEG, 62 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000195.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000134.JPEG, 63 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000196.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000166.JPEG, 64 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000197.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000165.JPEG, 65 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000198.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000181.JPEG, 66 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000199.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000167.JPEG, 67 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000200.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000169.JPEG, 68 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000201.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000183.JPEG, 69 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000202.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000158.JPEG, 70 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000203.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000170.JPEG, 71 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000160.JPEG, 72 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000204.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000205.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000172.JPEG, 73 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000206.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000171.JPEG, 74 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000207.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000188.JPEG, 75 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000208.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000174.JPEG, 76 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000120.JPEG, 77 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000209.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000210.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000178.JPEG, 78 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000211.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000193.JPEG, 79 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000212.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000194.JPEG, 80 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000213.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000177.JPEG, 81 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000214.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000179.JPEG, 82 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000215.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000182.JPEG, 83 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000216.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000195.JPEG, 84 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000217.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000199.JPEG, 85 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000218.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000180.JPEG, 86 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000219.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000185.JPEG, 87 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000220.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000184.JPEG, 88 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000221.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000192.JPEG, 89 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000222.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000190.JPEG, 90 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000187.JPEG, 91 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000223.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000224.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000205.JPEG, 92 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000204.JPEG, 93 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000225.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000226.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000189.JPEG, 94 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000227.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000208.JPEG, 95 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000228.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000175.JPEG, 96 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000229.JPEG
# ...
# Downloading batchscoring/images/ILSVRC2012_val_00000924.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000925.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000893.JPEG, 793 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000894.JPEG, 794 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000897.JPEG, 795 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000926.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000927.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000928.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000890.JPEG, 796 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000895.JPEG, 797 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000929.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000930.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000901.JPEG, 798 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000907.JPEG, 799 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000931.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000899.JPEG, 800 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000932.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000905.JPEG, 801 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000933.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000904.JPEG, 802 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000934.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000935.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000900.JPEG, 803 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000936.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000902.JPEG, 804 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000912.JPEG, 805 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000937.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000938.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000903.JPEG, 806 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000906.JPEG, 807 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000939.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000940.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000909.JPEG, 808 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000913.JPEG, 809 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000911.JPEG, 810 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000941.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000942.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000943.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000919.JPEG, 811 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000908.JPEG, 812 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000944.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000945.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000920.JPEG, 813 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000946.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000917.JPEG, 814 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000947.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000910.JPEG, 815 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000916.JPEG, 816 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000948.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000949.JPEG
# Downloaded batchscoring/images/ILSVRC2012_val_00000921.JPEG, 817 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000918.JPEG, 818 files out of an estimated total of 899
# Downloaded batchscoring/images/ILSVRC2012_val_00000923.JPEG, 819 files out of an estimated total of 899
# Downloading batchscoring/images/ILSVRC2012_val_00000950.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000951.JPEG
# Downloading batchscoring/images/ILSVRC2012_val_00000952.JPEG
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/05/05 08:58:25 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-05T08:58:26.965627
# Starting the daemon thread to refresh tokens in background for process with pid = 151
# Entering Run History Context Manager.
# Initialize DatasetContextManager.
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.4.0.post2 azureml-dataprep==1.5.0
# Processing 'input_images'
# Processing dataset FileDataset
# {
#   "source": [
#     "('images_datastore', 'batchscoring/images/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "14a8e4f0-873b-43fc-8c57-29c655c995e9",
#     "name": "input_images",
#     "version": 1,
#     "workspace": "Workspace.create(name='MyFirstML', subscription_id='e52443a5-2969-41ea-8e65-0949be111242', resource_group='FaceRec')"
#   }
# }
# Looking for variable: AZUREML_DATAREFERENCE_input_images_0
# Variable value: /tmp/d0c40209-864f-44bf-9177-a9e11932fcb9/batchscoring/images/
# Dataset 'input_images' converted to DataReference.
# Set INPUT_IMAGES=/tmp/d0c40209-864f-44bf-9177-a9e11932fcb9/batchscoring/images/, skipping mount.
# Exit __enter__ of DatasetContextManager
# Preparing to call script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.4.0', '--scoring_module_name', 'batch_scoring.py', '--input_format', 'None', '--mini_batch_size', '20', '--error_threshold', '1', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/myfirstml/azureml/473e9f50-8536-49ad-b863-e7cad21021b4/mounts/workspaceblobstore/azureml/473e9f50-8536-49ad-b863-e7cad21021b4/scores', '--process_count_per_node', '2', '--model_name', 'inception', '--labels_name', 'label_ds', '--input_fds_0', 'input_images', '--input1', '/tmp/d0c40209-864f-44bf-9177-a9e11932fcb9/batchscoring/images/']
# After variable expansion, calling script [ driver/amlbi_main.py ] with arguments: ['--client_sdk_version', '1.4.0', '--scoring_module_name', 'batch_scoring.py', '--input_format', 'None', '--mini_batch_size', '20', '--error_threshold', '1', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/myfirstml/azureml/473e9f50-8536-49ad-b863-e7cad21021b4/mounts/workspaceblobstore/azureml/473e9f50-8536-49ad-b863-e7cad21021b4/scores', '--process_count_per_node', '2', '--model_name', 'inception', '--labels_name', 'label_ds', '--input_fds_0', 'input_images', '--input1', '/tmp/d0c40209-864f-44bf-9177-a9e11932fcb9/batchscoring/images/']
#
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /azureml-envs/azureml_2e3e343c7065686a0681d7d07e4ade14/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Starting the daemon thread to refresh tokens in background for process with pid = 151
#
#
# The experiment completed successfully. Finalizing run...
# Enter __exit__ of DatasetContextManager
# Exit __exit__ of DatasetContextManager
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 4 items cleaning up...
# Cleanup took 0.3108334541320801 seconds
#
# Streaming azureml-logs/75_job_post-tvmps_e69847f382fde179d7e8996f567b0b8211721240d7a074ff447edc7ed5f1d273_p.txt
# ===============================================================================================================
# Entering job release. Current time:2020-05-05T09:08:43.459720
# Starting job release. Current time:2020-05-05T09:08:44.249521
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 8787
# Entering context manager injector. Current time:2020-05-05T09:08:44.266985
# Job release is complete. Current time:2020-05-05T09:08:47.017718
#
# StepRun(batchscoring-202005050840) Execution Summary
# =====================================================
# StepRun( batchscoring-202005050840 ) Status: Finished
# {'runId': '473e9f50-8536-49ad-b863-e7cad21021b4', 'target': 'gpu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-05-05T08:56:21.192973Z', 'endTimeUtc': '2020-05-05T09:08:57.811535Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '84f3e45c-929a-4576-a0b9-f803c2888a63', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '90a158f1-4c6b-4c68-978f-73f6275c3a18', 'azureml.pipelinerunid': 'dc4bebc2-709e-4c4a-8025-bde64ab6e8ad', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '14a8e4f0-873b-43fc-8c57-29c655c995e9'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_images', 'mechanism': 'Mount', 'pathOnCompute': 'ebc2bca7-f0fd-421a-92d4-1c5bf90c6a33'}}, {'dataset': {'id': '7b1b413f-cdc3-406d-93c9-e38142067852'}, 'consumptionDetails': {'type': 'Reference'}}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.4.0', '--scoring_module_name', 'batch_scoring.py', '--input_format', 'None', '--mini_batch_size', '$AML_PARAMETER_aml_mini_batch_size', '--error_threshold', '$AML_PARAMETER_aml_error_threshold', '--output_action', 'append_row', '--logging_level', '$AML_PARAMETER_aml_logging_level', '--run_invocation_timeout', '$AML_PARAMETER_aml_run_invocation_timeout', '--output', '$AZUREML_DATAREFERENCE_scores', '--process_count_per_node', '$AML_PARAMETER_aml_process_count_per_node', '--model_name', 'inception', '--labels_name', 'label_ds', '--input_fds_0', 'input_images', '--input1', '$AZUREML_DATAREFERENCE_input_images_0'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'gpu-cluster', 'dataReferences': {'input_images_0': {'dataStoreName': 'images_datastore', 'mode': 'Download', 'pathOnDataStore': 'batchscoring/images/', 'pathOnCompute': None, 'overwrite': False}, 'scores': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/473e9f50-8536-49ad-b863-e7cad21021b4/scores', 'pathOnCompute': 'batchscoring/results', 'overwrite': False}}, 'data': {'input_images': {'dataLocation': {'dataset': {'id': '14a8e4f0-873b-43fc-8c57-29c655c995e9'}, 'dataPath': None}, 'createOutputDirectories': False, 'mechanism': 'Mount', 'environmentVariableName': 'input_images', 'pathOnCompute': 'ebc2bca7-f0fd-421a-92d4-1c5bf90c6a33', 'overwrite': False}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment batch_scoring Environment', 'version': 'Autosave_2020-05-05T08:41:09Z_3a72a9ad', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['tensorflow-gpu==1.13.1', 'azureml-defaults', 'azure-storage-queue~=2.1', 'azure-storage-common~=2.1', 'azureml-core~=1.0', 'azureml-telemetry~=1.0', 'filelock~=3.0', 'azureml-dataprep[fuse,pandas]~=1.1']}, 'psutil'], 'name': 'azureml_2e3e343c7065686a0681d7d07e4ade14'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'AML_PARAMETER_aml_mini_batch_size': '20', 'AML_PARAMETER_aml_error_threshold': '1', 'AML_PARAMETER_aml_logging_level': 'INFO', 'AML_PARAMETER_aml_run_invocation_timeout': '60', 'AML_PARAMETER_aml_process_count_per_node': '2'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base-gpu:intelmpi2018.3-cuda10.0-cudnn7-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'p ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'dc4bebc2-709e-4c4a-8025-bde64ab6e8ad', 'status': 'Completed', 'startTimeUtc': '2020-05-05T08:40:39.96837Z', 'endTimeUtc': '2020-05-05T09:09:03.531175Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"aml_mini_batch_size":"20","aml_error_threshold":"1","aml_logging_level":"INFO","aml_run_invocation_timeout":"60","aml_process_count_per_node":"2","aml_node_count":"1"}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://myfirstml6917184243.blob.core.windows.net/azureml/ExperimentRun/dcid.dc4bebc2-709e-4c4a-8025-bde64ab6e8ad/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=mEwx8OKK404Ejrp%2BIhxj8lW%2FAY7lryigjlL88uUKEzo%3D&st=2020-05-05T08%3A59%3A06Z&se=2020-05-05T17%3A09%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://myfirstml6917184243.blob.core.windows.net/azureml/ExperimentRun/dcid.dc4bebc2-709e-4c4a-8025-bde64ab6e8ad/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=IuEwcA5Rz2%2FXiMSPkd4HaVVWkDh%2FUwBT11KN5ALfTpw%3D&st=2020-05-05T08%3A59%3A06Z&se=2020-05-05T17%3A09%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://myfirstml6917184243.blob.core.windows.net/azureml/ExperimentRun/dcid.dc4bebc2-709e-4c4a-8025-bde64ab6e8ad/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=zWJC1t%2FQPTJGT9GbnMy9Mp%2FQvewg6ur4m9fWZeSCOiA%3D&st=2020-05-05T08%3A59%3A06Z&se=2020-05-05T17%3A09%3A06Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ### Download and review output

# %% [markdown]
# Run the following code to download the output file created from the `batch_scoring.py` script, then explore the scoring results.

# %%
batch_run = next(pipeline_run.get_children())
batch_output = batch_run.get_output_data("scores")
batch_output.download(local_path="inception_results")

import pandas as pd
for root, dirs, files in os.walk("inception_results"):
    for file in files:
        if file.endswith("parallel_run_step.txt"):
            result_file = os.path.join(root,file)

df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["Filename", "Prediction"]
print("Prediction has ", df.shape[0], " rows")
df.head(10)
# Out:
# Prediction has  899  rows
#                        Filename                   Prediction
# 0  ILSVRC2012_val_00000594.JPEG   Greater Swiss Mountain dog
# 1  ILSVRC2012_val_00000817.JPEG                      maypole
# 2  ILSVRC2012_val_00000616.JPEG                   hair slide
# 3  ILSVRC2012_val_00000132.JPEG                         file
# 4  ILSVRC2012_val_00000391.JPEG              Norfolk terrier
# 5  ILSVRC2012_val_00000876.JPEG                  hand blower
# 6  ILSVRC2012_val_00000393.JPEG            Shetland sheepdog
# 7  ILSVRC2012_val_00000202.JPEG                      bow tie
# 8  ILSVRC2012_val_00000205.JPEG               dial telephone
# 9  ILSVRC2012_val_00000930.JPEG           leatherback turtle

# %% [markdown]
# ## Publish and run from REST endpoint

# %% [markdown]
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Inception_v3_scoring", description="Batch scoring using Inception v3 model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Inception_v3_scoring,
# Id: 43c32ead-5012-4709-ade3-11aae4550653,
# Status: Active,
# Endpoint: https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/e52443a5-2969-41ea-8e65-0949be111242/resourceGroups/FaceRec/providers/Microsoft.MachineLearningServices/workspaces/MyFirstML/PipelineRuns/PipelineSubmit/43c32ead-5012-4709-ade3-11aae4550653)

# %% [markdown]
# To run the pipeline from the REST endpoint, you first need an OAuth2 Bearer-type authentication header. This example uses interactive authentication for illustration purposes, but for most production scenarios requiring automated or headless authentication, use service principle authentication as [described in this notebook](https://aka.ms/pl-restep-auth).
#
# Service principle authentication involves creating an **App Registration** in **Azure Active Directory**, generating a client secret, and then granting your service principal **role access** to your machine learning workspace. You then use the [`ServicePrincipalAuthentication`](https://docs.microsoft.com/python/api/azureml-core/azureml.core.authentication.serviceprincipalauthentication?view=azure-ml-py) class to manage your auth flow.
#
# Both `InteractiveLoginAuthentication` and `ServicePrincipalAuthentication` inherit from `AbstractAuthentication`, and in both cases you use the `get_authentication_header()` function in the same way to fetch the header.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the `endpoint` property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the `process_count_per_node` is passed through to `ParallelRunStep` because you defined it is defined as a `PipelineParameter` object in the step configuration.
#
# Make the request to trigger the run. Access the `Id` key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "batch_scoring",
                               "ParameterAssignments": {"process_count_per_node": 6}})

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  434ecb41-6c93-4246-8009-6fb65962fb9e

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["batch_scoring"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %% [markdown]
# ## Clean up resources
#
# Do not complete this section if you plan on running other Azure Machine Learning service tutorials.
#
# ### Stop the notebook VM
#
# If you used a cloud notebook server, stop the VM when you are not using it to reduce cost.
#
# 1. In your workspace, select **Compute**.
# 1. Select the **Notebook VMs** tab in the compute page.
# 1. From the list, select the VM.
# 1. Select **Stop**.
# 1. When you're ready to use the server again, select **Start**.
#
# ### Delete everything
#
# If you don't plan to use the resources you created, delete them, so you don't incur any charges.
#
# 1. In the Azure portal, select **Resource groups** on the far left.
# 1. From the list, select the resource group you created.
# 1. Select **Delete resource group**.
# 1. Enter the resource group name. Then select **Delete**.
#
# You can also keep the resource group but delete a single workspace. Display the workspace properties and select **Delete**.

# %% [markdown]
# ## Next steps
#
# In this machine learning pipelines tutorial, you did the following tasks:
#
# > * Built a pipeline with environment dependencies to run on a remote GPU compute resource
# > * Created a scoring script to run batch predictions with a pre-trained Tensorflow model
# > * Published a pipeline and enabled it to be run from a REST endpoint
#
# See the [how-to](https://docs.microsoft.com/azure/machine-learning/service/how-to-create-your-first-pipeline?view=azure-devops) for additional detail on building pipelines with the machine learning SDK.
